# %% [markdown]
# # Session 7

# %% [markdown]
# ## Python for Data Science
# >Pandas

# %% [markdown]
# ## Data Frames Methods

# %%
import numpy as n
import pandas as p


cars = p.read_csv("../Data/One/Cars.csv")

# %%
from IPython.core.display import HTML

display(HTML(cars.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>HP</th>
#       <th>MPG</th>
#       <th>VOL</th>
#       <th>SP</th>
#       <th>WT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>49</td>
#       <td>53.700681</td>
#       <td>89</td>
#       <td>104.185353</td>
#       <td>28.762059</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>55</td>
#       <td>50.013401</td>
#       <td>92</td>
#       <td>105.461264</td>
#       <td>30.466833</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>55</td>
#       <td>50.013401</td>
#       <td>92</td>
#       <td>105.461264</td>
#       <td>30.193597</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>70</td>
#       <td>45.696322</td>
#       <td>92</td>
#       <td>113.461264</td>
#       <td>30.632114</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>53</td>
#       <td>50.504232</td>
#       <td>92</td>
# ...

# %%
cars.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
cars.max()
# Out:
# HP     322.000000
# MPG     53.700681
# VOL    160.000000
# SP     169.598513
# WT      52.997752
# dtype: float64

# %%
cars.min()
# Out:
# HP     49.000000
# MPG    12.101263
# VOL    50.000000
# SP     99.564907
# WT     15.712859
# dtype: float64

# %% [markdown]
# # Value Count

# %%
cars['HP'].value_counts(6)
# Out:
# 92     0.086420
# 115    0.061728
# 95     0.061728
# 102    0.061728
# 165    0.049383
# 100    0.049383
# 140    0.049383
# 73     0.037037
# 90     0.037037
# 130    0.037037
# 55     0.037037
# 162    0.024691
# 84     0.024691
# 81     0.024691
# 78     0.024691
# 70     0.024691
# 62     0.024691
# 160    0.012346
# 280    0.012346
# 52     0.012346
# 150    0.012346
# 145    0.012346
# 295    0.012346
# 175    0.012346
# 263    0.012346
# 49     0.012346
# 322    0.012346
# 53     0.012346
# 66     0.012346
# 120    0.012346
# 80     0.012346
# 93     0.012346
# 96     0.012346
# 98     0.012346
# 103    0.012346
# 180    0.012346
# 236    0.012346
# 238    0.012346
# 245    0.012346
# 74     0.012346
# Name: HP, dtype: float64

# %% [markdown]
# ## Finding Mean of top 50 Records

# %%
top_50_records = cars.head(50)

mean = (n.mean(top_50_records))
mean
# Out:
# HP      85.520000
# MPG     40.041582
# VOL     92.360000
# SP     114.474373
# WT      30.281234
# dtype: float64

# %% [markdown]
# ## Changing the file to Salaries

# %%
salaries = p.read_csv("../Data/One/Salaries.csv")
display(HTML(salaries.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>rank</th>
#       <th>discipline</th>
#       <th>phd</th>
#       <th>service</th>
#       <th>sex</th>
#       <th>salary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Prof</td>
#       <td>B</td>
#       <td>56</td>
#       <td>49</td>
#       <td>Male</td>
#       <td>186960</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Prof</td>
#       <td>A</td>
#       <td>12</td>
#       <td>6</td>
#       <td>Male</td>
#       <td>93000</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Prof</td>
#       <td>A</td>
#       <td>23</td>
#       <td>20</td>
#       <td>Male</td>
#       <td>110515</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Prof</td>
#       <td>A</td>
#       <td>40</td>
#       <td>31</td>
#       <td>Male</td>
#       <td>131205</td>
#     </tr>
#     <tr>
#       <th>4</th>
# ...

# %% [markdown]
# ## Finding mean in salaries for top few records

# %%
n.mean(salaries.head(50))
# Out:
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %% [markdown]
# ## Finding Mean for bottom 50 values

# %%
n.mean(salaries.tail(50))
# Out:
# phd            17.14
# service        12.50
# salary     104533.98
# dtype: float64

# %% [markdown]
# ## Sorting Data In Pandas

# %%
salaries.sort_values(by="salary", ascending=True)
# Out:
#          rank discipline  phd  service     sex  salary
# 9        Prof          A   51       51    Male   57800
# 54  AssocProf          A   25       22  Female   62884
# 66   AsstProf          A    7        6  Female   63100
# 71  AssocProf          B   12        9  Female   71065
# 57   AsstProf          A    3        1  Female   72500
# ..        ...        ...  ...      ...     ...     ...
# 31       Prof          B   22       21    Male  155750
# 27       Prof          A   45       43    Male  155865
# 72       Prof          B   24       15  Female  161101
# 13       Prof          B   35       33    Male  162200
# 0        Prof          B   56       49    Male  186960
#
# [78 rows x 6 columns]

# %% [markdown]
# ## Picking a particular column
# - Using .col_name property
# - Using ['col_name'] index

# %%
salaries.salary
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %% [markdown]
# ### Displaying a Particular column
# > using index

# %%
salaries['rank']
# Out:
# 0          Prof
# 1          Prof
# 2          Prof
# 3          Prof
# 4          Prof
#         ...
# 73         Prof
# 74    AssocProf
# 75         Prof
# 76         Prof
# 77         Prof
# Name: rank, Length: 78, dtype: object

# %% [markdown]
# > using .col_name

# %%
salaries.phd
# Out:
# 0     56
# 1     12
# 2     23
# 3     40
# 4     20
#       ..
# 73    18
# 74    19
# 75    17
# 76    28
# 77    23
# Name: phd, Length: 78, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# df = sns.load_dataset(q9_data)
fig2 = plt.figure(figsize=(15,7))
# plot of 2 variables
p1=sns.kdeplot(salaries["phd"], shade=True, color="g")

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-ffc2644131ed> in <module>
# ----> 1 salaries["phd"].out
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'out'

# %%
salaries.salary
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %% [markdown]
# > Picking up multiple columns
#
# >>Also called data frame slicing

# %%
salaries[['rank','phd']]
# Out:
#          rank  phd
# 0        Prof   56
# 1        Prof   12
# 2        Prof   23
# 3        Prof   40
# 4        Prof   20
# ..        ...  ...
# 73       Prof   18
# 74  AssocProf   19
# 75       Prof   17
# 76       Prof   28
# 77       Prof   23
#
# [78 rows x 2 columns]

# %% [markdown]
# ### Finding the number of values of a Column
# > Using count() Funtion

# %%
salaries['phd'].count()
# Out:
# 78

# %% [markdown]
# ### Basic Statistics for the phd column

# %%
salaries['phd'].describe()
# Out:
# count    78.000000
# mean     19.705128
# std      12.498425
# min       1.000000
# 25%      10.250000
# 50%      18.500000
# 75%      27.750000
# max      56.000000
# Name: phd, dtype: float64

# %% [markdown]
# ### Finding Average inside PHD column

# %%
salaries['phd'].mean()
# Out:
# 19.705128205128204

# %% [markdown]
# ## Data Frames groupby Methods
# > Using groupby method

# %%
display(HTML(salaries.to_html()))    #just displaying data again to check
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>rank</th>
#       <th>discipline</th>
#       <th>phd</th>
#       <th>service</th>
#       <th>sex</th>
#       <th>salary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Prof</td>
#       <td>B</td>
#       <td>56</td>
#       <td>49</td>
#       <td>Male</td>
#       <td>186960</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Prof</td>
#       <td>A</td>
#       <td>12</td>
#       <td>6</td>
#       <td>Male</td>
#       <td>93000</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Prof</td>
#       <td>A</td>
#       <td>23</td>
#       <td>20</td>
#       <td>Male</td>
#       <td>110515</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Prof</td>
#       <td>A</td>
#       <td>40</td>
#       <td>31</td>
#       <td>Male</td>
#       <td>131205</td>
#     </tr>
#     <tr>
#       <th>4</th>
# ...

# %%
salaries.groupby('discipline').mean()
# Out:
#                   phd    service         salary
# discipline
# A           21.527778  15.722222   98331.111111
# B           18.142857  14.476190  116331.785714

# %% [markdown]
# ## Data Frame Method iloc
# - Iloc means ith location

# %%
salaries.iloc[5]
# Out:
# rank            Prof
# discipline         A
# phd               20
# service           20
# sex             Male
# salary        122400
# Name: 5, dtype: object

# %%
salaries.iloc[1:10, 0:2]
# Out:
#         rank discipline
# 1       Prof          A
# 2       Prof          A
# 3       Prof          A
# 4       Prof          B
# 5       Prof          A
# 6  AssocProf          A
# 7       Prof          A
# 8       Prof          A
# 9       Prof          A
